# %%
from logs.analysis_functions import plot_average_performance
from logs.logging import read_logs
import numpy as np

# %% [markdown]
# ### Generate a figure instance

# %%
import matplotlib.pyplot as plt

plt.figure()  # Create a new figure for loss

# %% [markdown]
# ### Read files and Plot the figure with graphs
# ##### Client | Accuracies | download from the the root | Comparison:server adaptation vs client adaptation | {1} UTA, {1, 2, 4, 8} UTA, {1, 2, 4, 8} DTA | abrupt

# %%
# {1} - server adapt UTA
drifted_client = read_logs('logs//saved_logs//paper//1//8_abrupt_downloadfromroot_serveradapt//drifted_client_log.pkl')
drifted_client_avg = read_logs('logs//saved_logs//paper//1//8_abrupt_downloadfromroot_serveradapt//drifted_client_avg_log.pkl')
non_drifted_client = read_logs('logs//saved_logs//paper//1//8_abrupt_downloadfromroot_serveradapt//non_drifted_client_log.pkl')
non_drifted_client_avg = read_logs('logs//saved_logs//paper//1//8_abrupt_downloadfromroot_serveradapt//non_drifted_client_avg_log.pkl')
color ="dodgerblue"
linestyle=":"

####################################
# ACCURACY
####################################
#------------
# DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
drifted_client_accuracies = []
non_drifted_client_accuracies = []

# Indicate the indices of the accuracy value and accuracy value in the tuple
ACCURACY_INDEX = 1

# Get the total number of clients to iterate
num_clients = len(drifted_client[0])

# Collect accuracies for each client across all rounds. Note: Here client_id = index of the client in the list
for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(drifted_client)):
        client_accuracies.append(drifted_client[round_index][client_id][ACCURACY_INDEX])
    drifted_client_accuracies.append(client_accuracies)
    
# # Plot the accuracy of each client against the number of rounds
# plt.figure()  # Create a new figure for accuracy

# Transpose to get accuracies for all clients at each round
drifted_client_accuracies_transposed = np.array(drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = drifted_client_accuracies_transposed.min(axis=1)
acc_max = drifted_client_accuracies_transposed.max(axis=1)

#------------
# NON-DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
non_drifted_client_accuracies = []

# Get the total number of clients to iterate
num_clients = len(non_drifted_client[0])

for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(non_drifted_client)):
        client_accuracies.append(non_drifted_client[round_index][client_id][ACCURACY_INDEX])
    non_drifted_client_accuracies.append(client_accuracies)

# Transpose to get accuracies for all clients at each round
non_drifted_client_accuracies_transposed = np.array(non_drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = non_drifted_client_accuracies_transposed.min(axis=1)
acc_max = non_drifted_client_accuracies_transposed.max(axis=1)

# Extract the accuracy values from the list of tuples
drifted_client_avg_accuracies = [x[0] for x in drifted_client_avg]
non_drifted_client_avg_accuracies = [x[0] for x in non_drifted_client_avg]

# Plot the average accuracy of the clients against the number of rounds
line1, = plt.plot(drifted_client_avg_accuracies, label='{1} server adapts, UTA', linestyle=linestyle, color=color )
line2, = plt.plot(non_drifted_client_avg_accuracies, linestyle=linestyle, color=color)

# %%
# {1} - client adapt UTA
drifted_client = read_logs('logs//saved_logs//paper//1//6_abrupt_downloadfromroot//drifted_client_log.pkl')
drifted_client_avg = read_logs('logs//saved_logs//paper//1//6_abrupt_downloadfromroot//drifted_client_avg_log.pkl')
non_drifted_client = read_logs('logs//saved_logs//paper//1//6_abrupt_downloadfromroot//non_drifted_client_log.pkl')
non_drifted_client_avg = read_logs('logs//saved_logs//paper//1//6_abrupt_downloadfromroot//non_drifted_client_avg_log.pkl')
color ="blue"
linestyle="--"

####################################
# ACCURACY
####################################
#------------
# DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
drifted_client_accuracies = []
non_drifted_client_accuracies = []

# Indicate the indices of the accuracy value and accuracy value in the tuple
ACCURACY_INDEX = 1

# Get the total number of clients to iterate
num_clients = len(drifted_client[0])

# Collect accuracies for each client across all rounds. Note: Here client_id = index of the client in the list
for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(drifted_client)):
        client_accuracies.append(drifted_client[round_index][client_id][ACCURACY_INDEX])
    drifted_client_accuracies.append(client_accuracies)
    
# # Plot the accuracy of each client against the number of rounds
# plt.figure()  # Create a new figure for accuracy

# Transpose to get accuracies for all clients at each round
drifted_client_accuracies_transposed = np.array(drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = drifted_client_accuracies_transposed.min(axis=1)
acc_max = drifted_client_accuracies_transposed.max(axis=1)

#------------
# NON-DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
non_drifted_client_accuracies = []

# Get the total number of clients to iterate
num_clients = len(non_drifted_client[0])

for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(non_drifted_client)):
        client_accuracies.append(non_drifted_client[round_index][client_id][ACCURACY_INDEX])
    non_drifted_client_accuracies.append(client_accuracies)

# Transpose to get accuracies for all clients at each round
non_drifted_client_accuracies_transposed = np.array(non_drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = non_drifted_client_accuracies_transposed.min(axis=1)
acc_max = non_drifted_client_accuracies_transposed.max(axis=1)

# Extract the accuracy values from the list of tuples
drifted_client_avg_accuracies = [x[0] for x in drifted_client_avg]
non_drifted_client_avg_accuracies = [x[0] for x in non_drifted_client_avg]

# Plot the average accuracy of the clients against the number of rounds
line3, = plt.plot(drifted_client_avg_accuracies, label='{1} client adapts, UTA', linestyle=linestyle, color=color )
line4, = plt.plot(non_drifted_client_avg_accuracies, linestyle=linestyle, color=color)

# %%
#{1_2_4_8} server adapts UTA
drifted_client = read_logs('logs//saved_logs//paper//1_2_4_8//57_abrupt_downloadfromroot_serveradapt//drifted_client_log.pkl')
drifted_client_avg = read_logs('logs//saved_logs//paper//1_2_4_8//57_abrupt_downloadfromroot_serveradapt//drifted_client_avg_log.pkl')
non_drifted_client = read_logs('logs//saved_logs//paper//1_2_4_8//57_abrupt_downloadfromroot_serveradapt//non_drifted_client_log.pkl')
non_drifted_client_avg = read_logs('logs//saved_logs//paper//1_2_4_8//57_abrupt_downloadfromroot_serveradapt//non_drifted_client_avg_log.pkl')
color ="grey"
linestyle="-"

####################################
# ACCURACY
####################################
#------------
# DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
drifted_client_accuracies = []
non_drifted_client_accuracies = []

# Indicate the indices of the accuracy value and accuracy value in the tuple
ACCURACY_INDEX = 1

# Get the total number of clients to iterate
num_clients = len(drifted_client[0])

# Collect accuracies for each client across all rounds. Note: Here client_id = index of the client in the list
for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(drifted_client)):
        client_accuracies.append(drifted_client[round_index][client_id][ACCURACY_INDEX])
    drifted_client_accuracies.append(client_accuracies)
    
# # Plot the accuracy of each client against the number of rounds
# plt.figure()  # Create a new figure for accuracy

# Transpose to get accuracies for all clients at each round
drifted_client_accuracies_transposed = np.array(drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = drifted_client_accuracies_transposed.min(axis=1)
acc_max = drifted_client_accuracies_transposed.max(axis=1)

#------------
# NON-DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
non_drifted_client_accuracies = []

# Get the total number of clients to iterate
num_clients = len(non_drifted_client[0])

for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(non_drifted_client)):
        client_accuracies.append(non_drifted_client[round_index][client_id][ACCURACY_INDEX])
    non_drifted_client_accuracies.append(client_accuracies)

# Transpose to get accuracies for all clients at each round
non_drifted_client_accuracies_transposed = np.array(non_drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = non_drifted_client_accuracies_transposed.min(axis=1)
acc_max = non_drifted_client_accuracies_transposed.max(axis=1)

# Extract the accuracy values from the list of tuples
drifted_client_avg_accuracies = [x[0] for x in drifted_client_avg]
non_drifted_client_avg_accuracies = [x[0] for x in non_drifted_client_avg]

# Plot the average accuracy of the clients against the number of rounds
line5, = plt.plot(drifted_client_avg_accuracies, label='{1, 2, 4, 8} server adapts, UTA', linestyle=linestyle, color=color )
line6, = plt.plot(non_drifted_client_avg_accuracies, linestyle=linestyle, color=color)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 #{1_2_4_8} server adapts
# ----> 2 drifted_client = read_logs('logs//saved_logs//paper//1_2_4_8//57_abrupt_downloadfromroot_serveradapt//drifted_client_log.pkl')
#       3 drifted_client_avg = read_logs('logs//saved_logs//paper//1_2_4_8//57_abrupt_downloadfromroot_serveradapt//drifted_client_avg_log.pkl')
#       4 non_drifted_client = read_logs('logs//saved_logs//paper//1_2_4_8//57_abrupt_downloadfromroot_serveradapt//non_drifted_client_log.pkl')
#
# File D:\repos\federated_trees\logs\logging.py:52, in read_logs(file_name)
#      45 """
#      46 Read the loss and accuracy data from a binary file
#      47 :param file_name: Name of the file to read the logs
#      48 :return: List of tuples containing the loss and accuracy of the models for each client or server
#      49 """
#      51 # Read from a binary file
# ---> 52 with open(file_name, "rb") as file:
#      53     loss_and_accuracy = pickle.load(file)
#      55 return loss_and_accuracy
#
# FileNotFoundError: [Errno 2] No such file or directory: 'logs//saved_logs//paper//1_2_4_8//57_abrupt_downloadfromroot_serveradapt//drifted_client_log.pkl'

# %%
#{1_2_4_8} client adapts UTA
drifted_client = read_logs('logs//saved_logs//paper//1_2_4_8//47_abrupt_downloadfromroot//drifted_client_log.pkl')
drifted_client_avg = read_logs('logs//saved_logs//paper//1_2_4_8//47_abrupt_downloadfromroot//drifted_client_avg_log.pkl')
non_drifted_client = read_logs('logs//saved_logs//paper//1_2_4_8//47_abrupt_downloadfromroot//non_drifted_client_log.pkl')
non_drifted_client_avg = read_logs('logs//saved_logs//paper//1_2_4_8//47_abrupt_downloadfromroot//non_drifted_client_avg_log.pkl')
color ="black"
linestyle="-."

####################################
# ACCURACY
####################################
#------------
# DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
drifted_client_accuracies = []
non_drifted_client_accuracies = []

# Indicate the indices of the accuracy value and accuracy value in the tuple
ACCURACY_INDEX = 1

# Get the total number of clients to iterate
num_clients = len(drifted_client[0])

# Collect accuracies for each client across all rounds. Note: Here client_id = index of the client in the list
for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(drifted_client)):
        client_accuracies.append(drifted_client[round_index][client_id][ACCURACY_INDEX])
    drifted_client_accuracies.append(client_accuracies)
    
# # Plot the accuracy of each client against the number of rounds
# plt.figure()  # Create a new figure for accuracy

# Transpose to get accuracies for all clients at each round
drifted_client_accuracies_transposed = np.array(drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = drifted_client_accuracies_transposed.min(axis=1)
acc_max = drifted_client_accuracies_transposed.max(axis=1)

#------------
# NON-DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
non_drifted_client_accuracies = []

# Get the total number of clients to iterate
num_clients = len(non_drifted_client[0])

for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(non_drifted_client)):
        client_accuracies.append(non_drifted_client[round_index][client_id][ACCURACY_INDEX])
    non_drifted_client_accuracies.append(client_accuracies)

# Transpose to get accuracies for all clients at each round
non_drifted_client_accuracies_transposed = np.array(non_drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = non_drifted_client_accuracies_transposed.min(axis=1)
acc_max = non_drifted_client_accuracies_transposed.max(axis=1)

# Extract the accuracy values from the list of tuples
drifted_client_avg_accuracies = [x[0] for x in drifted_client_avg]
non_drifted_client_avg_accuracies = [x[0] for x in non_drifted_client_avg]

# Plot the average accuracy of the clients against the number of rounds
line7, = plt.plot(drifted_client_avg_accuracies, label='{1, 2, 4, 8} client adapts, UTA', linestyle=linestyle, color=color )
line8, = plt.plot(non_drifted_client_avg_accuracies, linestyle=linestyle, color=color)

# %%
#{1_2_4_8} DTA server adapts
drifted_client = read_logs('logs//saved_logs//paper//1_2_4_8//32_abrupt_DTA_serveradapt//drifted_client_log.pkl')
drifted_client_avg = read_logs('logs//saved_logs//paper//1_2_4_8//32_abrupt_DTA_serveradapt//drifted_client_avg_log.pkl')
non_drifted_client = read_logs('logs//saved_logs//paper//1_2_4_8//32_abrupt_DTA_serveradapt//non_drifted_client_log.pkl')
non_drifted_client_avg = read_logs('logs//saved_logs//paper//1_2_4_8//32_abrupt_DTA_serveradapt//non_drifted_client_avg_log.pkl')
color ="lime"
linestyle=(0, (5, 10))

####################################
# ACCURACY
####################################
#------------
# DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
drifted_client_accuracies = []
non_drifted_client_accuracies = []

# Indicate the indices of the accuracy value and accuracy value in the tuple
ACCURACY_INDEX = 1

# Get the total number of clients to iterate
num_clients = len(drifted_client[0])

# Collect accuracies for each client across all rounds. Note: Here client_id = index of the client in the list
for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(drifted_client)):
        client_accuracies.append(drifted_client[round_index][client_id][ACCURACY_INDEX])
    drifted_client_accuracies.append(client_accuracies)
    
# # Plot the accuracy of each client against the number of rounds
# plt.figure()  # Create a new figure for accuracy

# Transpose to get accuracies for all clients at each round
drifted_client_accuracies_transposed = np.array(drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = drifted_client_accuracies_transposed.min(axis=1)
acc_max = drifted_client_accuracies_transposed.max(axis=1)

#------------
# NON-DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
non_drifted_client_accuracies = []

# Get the total number of clients to iterate
num_clients = len(non_drifted_client[0])

for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(non_drifted_client)):
        client_accuracies.append(non_drifted_client[round_index][client_id][ACCURACY_INDEX])
    non_drifted_client_accuracies.append(client_accuracies)

# Transpose to get accuracies for all clients at each round
non_drifted_client_accuracies_transposed = np.array(non_drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = non_drifted_client_accuracies_transposed.min(axis=1)
acc_max = non_drifted_client_accuracies_transposed.max(axis=1)

# Extract the accuracy values from the list of tuples
drifted_client_avg_accuracies = [x[0] for x in drifted_client_avg]
non_drifted_client_avg_accuracies = [x[0] for x in non_drifted_client_avg]

# Plot the average accuracy of the clients against the number of rounds
line9, = plt.plot(drifted_client_avg_accuracies, label='{1, 2, 4, 8} server adapts, DTA', linestyle=linestyle, color=color )
line10, = plt.plot(non_drifted_client_avg_accuracies, linestyle=linestyle, color=color)

# %%
#{1_2_4_8} client adapts DTA
drifted_client = read_logs('logs//saved_logs//paper//1_2_4_8//30_abrupt_DTA//drifted_client_log.pkl')
drifted_client_avg = read_logs('logs//saved_logs//paper//1_2_4_8//30_abrupt_DTA//drifted_client_avg_log.pkl')
non_drifted_client = read_logs('logs//saved_logs//paper//1_2_4_8//30_abrupt_DTA//non_drifted_client_log.pkl')
non_drifted_client_avg = read_logs('logs//saved_logs//paper//1_2_4_8//30_abrupt_DTA//non_drifted_client_avg_log.pkl')
color ="green"
linestyle=(0, (3, 10, 1, 10))

####################################
# ACCURACY
####################################
#------------
# DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
drifted_client_accuracies = []
non_drifted_client_accuracies = []

# Indicate the indices of the accuracy value and accuracy value in the tuple
ACCURACY_INDEX = 1

# Get the total number of clients to iterate
num_clients = len(drifted_client[0])

# Collect accuracies for each client across all rounds. Note: Here client_id = index of the client in the list
for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(drifted_client)):
        client_accuracies.append(drifted_client[round_index][client_id][ACCURACY_INDEX])
    drifted_client_accuracies.append(client_accuracies)
    
# # Plot the accuracy of each client against the number of rounds
# plt.figure()  # Create a new figure for accuracy

# Transpose to get accuracies for all clients at each round
drifted_client_accuracies_transposed = np.array(drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = drifted_client_accuracies_transposed.min(axis=1)
acc_max = drifted_client_accuracies_transposed.max(axis=1)

#------------
# NON-DRIFTED
#------------
# List to store the accuracy values of all clients across all rounds
non_drifted_client_accuracies = []

# Get the total number of clients to iterate
num_clients = len(non_drifted_client[0])

for client_id in range(num_clients):
    client_accuracies = []
    for round_index in range(len(non_drifted_client)):
        client_accuracies.append(non_drifted_client[round_index][client_id][ACCURACY_INDEX])
    non_drifted_client_accuracies.append(client_accuracies)

# Transpose to get accuracies for all clients at each round
non_drifted_client_accuracies_transposed = np.array(non_drifted_client_accuracies).T

# Calculate the minimum and maximum accuracies across clients for each round
acc_min = non_drifted_client_accuracies_transposed.min(axis=1)
acc_max = non_drifted_client_accuracies_transposed.max(axis=1)

# Extract the accuracy values from the list of tuples
drifted_client_avg_accuracies = [x[0] for x in drifted_client_avg]
non_drifted_client_avg_accuracies = [x[0] for x in non_drifted_client_avg]

# Plot the average accuracy of the clients against the number of rounds
line11, = plt.plot(drifted_client_avg_accuracies, label='{1, 2, 4, 8} client adapts, DTA', linestyle=linestyle, color=color )
line12, = plt.plot(non_drifted_client_avg_accuracies, linestyle=linestyle, color=color)

# %% [markdown]
# ### Save plots

# %%
from plots.plotting import configure_and_save_plot
import constants

# %%
y_label = 'Avg. Accuracy'
file_name = 'server_vs_client_adapt'
x_label = 'Rounds'
configure_and_save_plot(plt, x_label, y_label,_,constants.Paths.PLOT_SAVE_PATH + file_name, [line1, line3, line5, line7, line9, line11])
